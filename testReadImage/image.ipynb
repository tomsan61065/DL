# %%
import numpy as np
import matplotlib.pyplot as plt # plt 顯示圖
import matplotlib.image as mpimg # mpimg 讀圖
import cv2

# %%
img = cv2.imread("1_1.png")
print(img.shape)
img2 = cv2.imread("2_12.png")
print(img2.shape)
img3 = cv2.imread("3_1.png")
print(img3.shape)
img4 = cv2.imread("5_5.png")
print(img4.shape)
img5 = cv2.imread("10_1.png")
print(img5.shape)

img4r = cv2.resize(img4, (100, 32)) #cv2.resize(src, dsize[, dst[, fx[, fy[, interpolation]]]]) → dst
img4d = cv2.resize(img4r, (50, 16))
img5r = cv2.resize(img5, (100, 32))
# Out:
# (32, 100, 3)
# (32, 100, 3)
# (32, 100, 3)
# (33, 102, 3)
# (36, 110, 3)

# %%
#https://www.cnblogs.com/yinxiangnan-charles/p/5928689.html
plt.imshow(img) # 顯示圖片
plt.show()
plt.imshow(img2)
plt.show()
plt.imshow(img3)
plt.show()
plt.imshow(img4)
plt.show()
plt.imshow(img4r)
plt.show()
plt.imshow(img4d)
plt.show()
plt.imshow(img5)
plt.show()
plt.imshow(img5r)
plt.show()
#plt.axis('off') # 不顯示座標
